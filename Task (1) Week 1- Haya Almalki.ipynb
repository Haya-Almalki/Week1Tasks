# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

# %%
df= pd.read_csv("Task (1) Dataset.csv")

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (12316, 32)

# %%
drop_nul = ['Road_surface_type', 'Type_of_collision','Road_allignment','Area_accident_occured']
# Drop rows with null values in columns 
df2.dropna(subset=drop_nul, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[272], line 3
#       1 drop_nul = ['Road_surface_type', 'Type_of_collision','Road_allignment','Area_accident_occured']
#       2 # Drop rows with null values in columns
# ----> 3 df2.dropna(subset=drop_nul, inplace=True)
#
# NameError: name 'df2' is not defined

# %%
df['Educational_level'].unique()

# %%
# Fill null values for 'Educational_level' with Unknow
df['Educational_level'].fillna("Unknown", inplace=True)

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %%
df['Vehicle_driver_relation'].fillna("Unknown", inplace=True)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
df['Driving_experience'].fillna("unknown", inplace=True)

# %%
df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
df['Vehicle_movement'].fillna("Unknown", inplace=True)

# %%
df['Types_of_Junction'].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
df['Types_of_Junction'].fillna("Unknown", inplace=True)

# %%
df['Lanes_or_Medians'].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
df['Lanes_or_Medians'].fillna("Unknown", inplace=True)

# %%
df['Service_year_of_vehicle'].unique()
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
df['Service_year_of_vehicle'].mode()[0]
# Out:
# 'Unknown'

# %%
df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0], inplace=True)

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
df['Type_of_vehicle'].mode()[0]
# Out:
# 'Automobile'

# %%
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace=True)

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df['Owner_of_vehicle'].mode()[0]
# Out:
# 'Owner'

# %%
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace=True)

# %%
df['Defect_of_vehicle'].unique()
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
drop_col = ['Defect_of_vehicle', 'Work_of_casuality', 'Fitness_of_casuality']
df = df.drop(columns=drop_col, axis=1)

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Service_year_of_vehicle          0
# Area_accident_occured          239
# Lanes_or_Medians                 0
# Road_allignment                142
# Types_of_Junction                0
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement                 0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'Number_of_vehicles_involved'),
#   Text(1, 0, 'Number_of_casualties')])

# %%
import numpy as np

# Function to remove outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers from 'Fare' using the remove_outilers function (1 line)
df = remove_outliers(df, 'Number_of_vehicles_involved')
df = remove_outliers(df, 'Number_of_casualties')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'Number_of_vehicles_involved'),
#   Text(1, 0, 'Number_of_casualties')])

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Sex_of_casualty']
# Out:
# 0            na
# 1            na
# 2          Male
# 3        Female
# 4            na
#           ...
# 12309      Male
# 12311        na
# 12312        na
# 12314        na
# 12315    Female
# Name: Sex_of_casualty, Length: 7943, dtype: object

# %%
#Encoding sex of driver
mapping= {"Male":0,"Female":1,"Unknown":2}
df["Sex_of_driver_Encoding"]=df["Sex_of_driver"].map(mapping)

# %%
mapping= {"Male":0,"Female":1,"na":2}
df["Sex_of_casualty_Encoding"]=df["Sex_of_casualty"].map(mapping)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Age_band_of_driver_encoding'] = label_encoder.fit_transform(df['Age_band_of_driver'])

# %%
df['Type_of_vehicle_encoding']= label_encoder.fit_transform(df['Type_of_vehicle'])

# %%
df['Educational_level_encoding']= label_encoder.fit_transform(df['Educational_level'])

# %%
df['Day_of_week_encoding']= label_encoder.fit_transform(df['Day_of_week'])

# %%
df['Accident_severity_encoding']= label_encoder.fit_transform(df['Accident_severity'])

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7943 entries, 0 to 12315
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         7943 non-null   object
#  1   Day_of_week                  7943 non-null   object
#  2   Age_band_of_driver           7943 non-null   object
#  3   Sex_of_driver                7943 non-null   object
#  4   Educational_level            7943 non-null   object
#  5   Vehicle_driver_relation      7943 non-null   object
#  6   Driving_experience           7943 non-null   object
#  7   Type_of_vehicle              7943 non-null   object
#  8   Owner_of_vehicle             7943 non-null   object
#  9   Service_year_of_vehicle      7943 non-null   object
#  10  Area_accident_occured        7793 non-null   object
#  11  Lanes_or_Medians             7943 non-null   object
#  12  Road_allignment              7850 non-null   object
# ...

# %%
# convert time to date-time type
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# C:\Users\hayoo\AppData\Local\Temp\ipykernel_20512\1948108490.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                           7943                       7943.0
# mean   2024-07-25 14:08:57.242855424                          2.0
# min              2024-07-25 00:01:00                          2.0
# 25%              2024-07-25 10:07:00                          2.0
# 50%              2024-07-25 14:57:00                          2.0
# 75%              2024-07-25 18:05:00                          2.0
# max              2024-07-25 23:55:00                          2.0
# std                              NaN                          0.0
#
#        Number_of_casualties  Sex_of_driver_Encoding  Sex_of_casualty_Encoding  \
# count           7943.000000             7943.000000               7943.000000
# mean               1.346217                0.079063                  0.928239
# min                1.000000                0.000000                  0.000000
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.pairplot(df)
# Out:
# C:\Users\hayoo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
#define number of subplots
fig, axis = plt.subplots(5, 2,  figsize=(10,10))

#create histogram for each column in DataFrame
df.hist(ax=axis)
plt.subplots_adjust(hspace=0.6, wspace=0.6)

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
col_cor=df[['Age_band_of_driver_encoding', 'Accident_severity_encoding']]
cor_matrix=col_cor.corr()
cor_matrix
# Out:
#                              Age_band_of_driver_encoding  \
# Age_band_of_driver_encoding                     1.000000
# Accident_severity_encoding                      0.018269
#
#                              Accident_severity_encoding
# Age_band_of_driver_encoding                    0.018269
# Accident_severity_encoding                     1.000000

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.heatmap(cor_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
#bar plot for the most common day:
(df['Day_of_week'].value_counts() / len(df)).plot.bar()
plt.title('Day of the week')
plt.show()

# %%
plt.pie(x=df['Accident_severity'].value_counts().values,
        labels=df['Accident_severity'].value_counts().index,
        autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e376261c10>,
# ...
#  [Text(-1.013899903613202, 0.4266227671528324, 'Slight Injury'),
#   Text(1.0031344405719558, -0.4513549535990376, 'Serious Injury'),
#   Text(1.0996692828560894, -0.026971621063152176, 'Fatal injury')],
#  [Text(-0.5530363110617464, 0.23270332753790857, '87.3%'),
#   Text(0.5471642403119759, -0.2461936110540205, '11.9%'),
#   Text(0.5998196088305942, -0.014711793307173912, '0.8%')])

# %%
# Relative frequency bar plot for Sex_of_driver
(df['Sex_of_driver'].value_counts().head(10) / len(df)).plot.bar()
# Out:
# <Axes: xlabel='Sex_of_driver'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# * <h4>The day with the most accidents is Friday<h4/>
# * <h4>ٍThe percentage of sligth accidentst is higher<h4/>
# * <h4>Male accidentent is higher than Female <h4/>
